# %%
import numpy as np

test=np.random.rand(10,1) 

print(test)
# Out:
# [[0.8557965 ]
#  [0.93877131]
#  [0.37007192]
#  [0.03449841]
#  [0.67777405]
#  [0.08918597]
#  [0.516177  ]
#  [0.74121464]
#  [0.63395029]
#  [0.10294203]]

# %%
test[test<0.05]=0.1
print(test)
# Out:
# [[0.8557965 ]
#  [0.93877131]
#  [0.37007192]
#  [0.1       ]
#  [0.67777405]
#  [0.08918597]
#  [0.516177  ]
#  [0.74121464]
#  [0.63395029]
#  [0.10294203]]
